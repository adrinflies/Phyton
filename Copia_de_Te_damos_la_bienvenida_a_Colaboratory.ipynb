# %% [markdown]
# <a href="https://colab.research.google.com/github/adrinflies/Phyton/blob/main/Copia_de_Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Diciembre 8 2025
#
# ---

# %% [markdown]
# ## Tipos de datos

# %% [markdown]
# ## Operaciones

# %% [markdown]
# ## Operaciones de String

# %% [markdown]
# ## Operaciones Booleanas
